# %% [markdown]
# <a href="https://colab.research.google.com/github/Minyst/ML_DL_Portfolio/blob/main/YOLOv10%20Pretrained%20vs%20Custom/YOLOv10_Custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !curl -L "https://universe.roboflow.com/ds/rgovMIXJCK?key=fyU64pv91e" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git

# %%
# !pip install -q supervision roboflow

# %%
# !wget -P {HOME}/weights -q https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10n.pt

# %%
# %cd {HOME}

# !yolo task=detect mode=predict conf=0.25 save=True \
model={HOME}/weights/yolov10n.pt

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLOv10
import supervision as sv

# %%
import cv2
import numpy as np
from tqdm import tqdm
from google.colab.patches import cv2_imshow

# %%
output_video_path = '/content/PREMIER LEAGUE HIGHLIGHTS 10sec.mp4'

# %%
import cv2
import numpy as np
import supervision as sv
from ultralytics import YOLOv10
model = YOLOv10(f'{HOME}/weights/yolov10n.pt')
model.train(data='/content/data.yaml', epochs=100, imgsz=640)

# %%
model = YOLOv10('/content/runs/detect/train/weights/best.pt')

# %%
video_path = '/content/PREMIER LEAGUE HIGHLIGHTS 10sec.mp4'
frames = []
cap = cv2.VideoCapture(video_path)
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret:
        frames.append(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
    else:
        break

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_video.mp4', fourcc, 30, (852, 480))

for frame in tqdm(frames):
    results = model(frame)[0]
    detections = sv.Detections.from_ultralytics(results)
    bounding_box_annotator = sv.BoundingBoxAnnotator()
    label_annotator = sv.LabelAnnotator()

    annotated_image = bounding_box_annotator.annotate(
        scene=frame, detections=detections)
    annotated_image = label_annotator.annotate(
        scene=annotated_image, detections=detections)
    final_image = cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR)
    out.write(final_image)
out.release()

# %%
output_video_path = "/content/output_video.mp4"
new_video_path = "/content/new_video.mp4"

import locale
from IPython.display import HTML
from base64 import b64encode
locale.getpreferredencoding = lambda: "UTF-8"
# !ffmpeg -i {output_video_path} -vcodec libx264 {new_video_path}

mp4 = open("/content/new_video.mp4",'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=1000 controls>
    <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/output_video.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:10.00, start: 0.000000, bitrate: 7050 kb/s
#   Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 852x480 [SAR 1:1 DAR 71:40], 7048 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56cd60fc69c0] using SAR=1/1
# [libx264 @ 0x56cd60fc69c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56cd60fc69c0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x56cd60fc69c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/new_video.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 852x480 [SAR 1:1 DAR 71:40], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  300 fps= 38 q=-1.0 Lsize=    2212kB time=00:00:09.90 bitrate=1830.5kbits/s speed=1.26x
# video:2208kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.181193%
# [libx264 @ 0x56cd60fc69c0] frame I:2     Avg QP:21.54  size: 44009
# [libx264 @ 0x56cd60fc69c0] frame P:139   Avg QP:23.23  size: 11773
# [libx264 @ 0x56cd60fc69c0] frame B:159   Avg QP:27.88  size:  3371
# [libx264 @ 0x56cd60fc69c0] consecutive B-frames: 21.0% 17.3% 23.0% 38.7%
# [libx264 @ 0x56cd60fc69c0] mb I  I16..4: 15.1% 59.6% 25.3%
# [libx264 @ 0x56cd60fc69c0] mb P  I16..4:  2.3%  8.2%  2.1%  P16..4: 38.9% 12.4%  9.3%  0.0%  0.0%    skip:26.7%
# [libx264 @ 0x56cd60fc69c0] mb B  I16..4:  0.7%  1.3%  0.6%  B16..8: 38.8%  5.7%  2.0%  direct: 1.6%  skip:49.2%  L0:51.0% L1:38.1% BI:10.9%
# [libx264 @ 0x56cd60fc69c0] 8x8 transform intra:61.8% inter:63.4%
# [libx264 @ 0x56cd60fc69c0] coded y,uvDC,uvAC intra: 51.4% 61.2% 22.8% inter: 13.3% 14.5% 6.2%
# [libx264 @ 0x56cd60fc69c0] i16 v,h,dc,p: 26% 48% 21%  5%
# [libx264 @ 0x56cd60fc69c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 33% 42%  2%  1%  1%  1%  1%  3%
# [libx264 @ 0x56cd60fc69c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 32% 16%  3%  3%  4%  3%  3%  5%
# [libx264 @ 0x56cd60fc69c0] i8c dc,h,v,p: 39% 35% 23%  3%
# [libx264 @ 0x56cd60fc69c0] Weighted P-Frames: Y:0.7% UV:0.0%
# [libx264 @ 0x56cd60fc69c0] ref P L0: 71.6%  9.8% 13.4%  5.2%  0.0%
# [libx264 @ 0x56cd60fc69c0] ref B L0: 88.8%  9.8%  1.4%
# [libx264 @ 0x56cd60fc69c0] ref B L1: 98.9%  1.1%
# [libx264 @ 0x56cd60fc69c0] kb/s:1808.35
# <video width=1000 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
